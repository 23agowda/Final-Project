# %% [markdown]
# ## **Swimming Pools- Anushka**
#
# The data subset I chose to analyze in order to determine which neighborhood is the best for a penguin to live in is the City of Pittsburgh Pools. The "best neighborhood" is the one with the pool that holds the greatest capacity.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# I'm importing pandas, numpy, matplotlib, and geopandas.

# %%
data = pd.read_csv('PittsburghSwimming.csv', index_col="neighborhood", parse_dates=True)
data.head(28)
# Out:
#                           _id          id                   name        type  \
# neighborhood
# Bedford Dwellings           1   899591542                  Ammon        Pool
# Banksville                  2  1003800828             Banksville        Pool
# Beechview                   3  1688544652   Beechview Spray Park  Spray Park
# Bloomfield                  4  1533382756             Bloomfield        Pool
# Hazelwood                   5  1287441950     Burgwin Spray Park  Spray Park
# Troy Hill                   6   168387727      Cowley Spray Park  Spray Park
# East Hills                  7  1569871328  East Hills Spray Park  Spray Park
# Highland Park               8  1475037865    Highland - Children        Pool
# Highland Park               9     5446687        Highland - Main        Pool
# Homewood South             10   878134116               Homewood        Pool
# Brighton Heights           11  2092220498             Jack Stack        Pool
# ...

# %% [markdown]
# I have read in the CSV file, made the indexed collumn "neighborhoods" in order to display each neighborhood's data, and revealed all the neighborhood's data.

# %%
data.plot(rot = 35)
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:677: UserWarning: The handle <matplotlib.lines.Line2D object at 0x7f7c9bbbc1c0> has a label of '_id' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)

# %% [markdown]
# This doesn't look good

# %%
data.groupby("capacity")

# %% [markdown]
# It looks like the data is too big

# %%
pivoted_data = data.pivot_table(index="neighborhood", columns="type", values="capacity")
pivoted_data
# Out:
# type                     Pool
# neighborhood
# Allegheny Center     271000.0
# Banksville           166320.0
# Bedford Dwellings    538000.0
# Bloomfield           335000.0
# Brighton Heights     205800.0
# Brookline            417657.0
# Carrick              224100.0
# Greenfield           195000.0
# Highland Park        560242.0
# Homewood South       171075.0
# Lincoln Place         18000.0
# Mount Washington     356000.0
# Perry North          205800.0
# Polish Hill          215451.0
# Sheraden             278000.0
# South Side Flats     156400.0
# Squirrel Hill South  187600.0
# Westwood             156840.0

# %% [markdown]
# I pivoted the data by keeping the neighborhoods as the index, implementing the type of pools as the column in which the capactiy of each neighborhood's pool is shown.

# %%
pivoted_data.sample(5)
# Out:
# type                     Pool
# neighborhood
# Squirrel Hill South  187600.0
# Bloomfield           335000.0
# Brighton Heights     205800.0
# Carrick              224100.0
# Brookline            417657.0

# %% [markdown]
# I obtained a random sample of 5 neighborhood pool's with their capacity

# %%
pivoted_data.plot()
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# I plotted the pivoted data.

# %%
pivoted_data.cumsum().plot()
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# I ploted the cumulative sum of the pivoted data.

# %%
pivoted_data.plot.density()

# %% [markdown]
# I plotted the density of the pivoted data which shows that most pools' capacity is around 200,000.

# %%
pivoted_data.max()
# Out:
# type
# Pool    560242.0
# dtype: float64

# %% [markdown]
# I discovered that the maxium capacity a specific pool has in the dataset is 560,242.

# %%
for capacity in pivoted_data:
    if capacity == 560242.0:
        print('neighborhood')
    else:
        print('error')
# Out:
# error

# %% [markdown]
# I was trying to find which neighborhood correlated with the highest capacity pool. This gave me an error because I needed to iterate through the index (neighborhood) and column (pools) of my dataset.

# %%
for neighborhood in pivoted_data.index:
    for capacity in pivoted_data.columns:
        if 560242.0 == pivoted_data.loc[neighborhood, capacity]:
            print("Neighborhood:", neighborhood)
        else:
            break
# Out:
# Neighborhood: Highland Park

# %% [markdown]
# My outer *for* loop iterates through the pittsburgh neighborhoods because that is the index in my pivoted dataset. My inner *for* loop iterates through the capacity of the pools because that is the column in my pivoted dataset. My if-else statement obtains the specific neighborhood required from my index and column with the capacity of 560242.0.

# %%
pivoted_data.plot.bar(rot = 70)

# %% [markdown]
# This bar graph verifies that the neghborhood Highland Park has the swimming pool that possesses the highest capacity.

# %%
neighborhood_map = gpd.read_file('PittsburghSwimming.csv')
neighborhood_map.plot()

# %% [markdown]
# This didn't create a map of anything.

# %%
neighborhood_map = gpd.read_file('path/to/your/neighborhood_shapefile.shp')
merged_data = neighborhood_map.merge(pivoted_data, how='left', left_index=True, right_index=True)
merged_data.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: path/to/your/neighborhood_shapefile.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-8-667a9af33339> in <module>
# ----> 1 neighborhood_map = gpd.read_file('path/to/your/neighborhood_shapefile.shp')
#       2 merged_data = neighborhood_map.merge(pivoted_data, how='left', left_index=True, right_index=True)
#       3 merged_data.plot()
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ...

# %% [markdown]
# I'm having trouble converting my csv file to shapefile so it can be used with geopandas.
